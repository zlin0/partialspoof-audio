# %%
import numpy as np
import matplotlib.pyplot as plt 
from python_speech_features import sigproc
from scipy.fftpack import dct

# %%
from base import get_lfcc_filterbanks

# %%
lfcc=get_lfcc_filterbanks(nfilt=60)

# %%
for i in np.arange(60):
    plt.plot( ,lfcc[i])

# %%
from base import get_imel_filterbanks

# %%
fbank = get_imel_filterbanks(nfilt=20,nfft=512,samplerate=16000,lowfreq=0,highfreq=None)

# %%
for i in np.arange(20):
    plt.plot(fbank[i])

# %%
0.	Abs
•	Framework. 整体框架的提出。pipiline 
•	Feature. 有效的handcraft feature。-> 改名。+ Multimodal


1.	Intro 
    ASD
    PEP-3
    Previous study：ASD（Prosody），ML，看情况加入其他病理（ Parkinson，Dysarthria ）。
    Shortcoming of previous：pep3。相关研究少。依据：ASD时长…等有效，引出手工特征，引出自动化实验框架。
    Purpose of this paper: idea + task intro (PEP3)  
    paper structure.


2.	Database & feature
    2.1 & 2.2 Two Databases. 差->好 介绍数据库（性别，年龄，EL分布），录音笔，录音环境（图），SNR

    2.3 Feature
    Acoustic feature（opensmile，Fbank）
    Text Feature。（任务导向）
    Quality of Data。数据质量差->手工特征。


3.	Methods （pipline） &        4. Experiment  &  Results
    Phase I 手工特征（acoustic 和handcraft feature的对比 ） 【=>手工有效】
    Phase II 提出自动标注（pipline）。各种模块的性能对比。 
            ASR
            diarization（txt+acoustic）    
            EL mapping
            regression
            Phase I 和 II 的手工特征对比
            Phase II 自身的对比：一半手动标注效果和  一半训练得到另一半自动标注 对比。


5.	DISCUSS
•	Handcraft fature is more efficient. 手工特征有效
•	New framework: automatic annotation. 新的自动标注框架，提取手工特征，可以泛化到其他任务上。
•	Multimodal 
•	Future direction.
