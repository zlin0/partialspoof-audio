# %% [markdown]
# # Tutorial for partialspoof.audio

# %% [markdown]
# - intro
# - figure

# %% [markdown]
# # 0. Intro
#
# Folder follows kaldi's style
# local: \
# utils: \

# %% [markdown]
# ## 1. Pre-processing
#
# 1.1 normalization

# %% [markdown]
# * 1. using sv56 to do normalization on `utils/sub_sv56.sh`
#   2. P.S. For some data which is provided in flac format, we also need to convert it to wav using `sox`
#   3. Trim silence at head/tail of the audio (based on the VAD results from the next step 2 of VAD.)

# %% [markdown]
# 1.2 VAD/ASR

# %%
In this step, we can get npy style VAD vectors.

# %% [markdown]
# ## 3. Substitution and Concatenation

# %% [markdown]
# 1. cross-correlation

# %%
1.

# %% [markdown]
# Note:
# Since we are considering to generate data to ..
# partialspoof.audio support other setting to choose segments from the same gender.

# %% [markdown]
# ## Labeling

# %% [markdown]
# ## 4. Post-processing

# %% [markdown]
# 1. remove silecen in head and tail
# 2. remove short audio
# 3. combine the continous segments. shorter than the limited duration.
# 4.
